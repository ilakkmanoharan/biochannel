# %% [markdown]
# # Drug Response Predictor

# %%
# Install Kaggle API (if needed)
# !pip install -q kaggle

import os

# Upload kaggle.json manually in Kaggle or Colab if required
os.environ['KAGGLE_CONFIG_DIR'] = '/kaggle/working'

# Example: place kaggle.json in /kaggle/working before running

# %%
# !kaggle datasets download -d ghazaleh/gdsc-drug-response -p /kaggle/working --unzip

import pandas as pd
df = pd.read_csv('/kaggle/working/drug_response.csv')
df.head()

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import LabelEncoder

le1, le2 = LabelEncoder(), LabelEncoder()
df['cell'] = le1.fit_transform(df.iloc[:,0])
df['drug'] = le2.fit_transform(df.iloc[:,1])

X = df[['cell','drug']]
y = df.iloc[:,2]

model = RandomForestRegressor()
model.fit(X,y)
model.predict(X[:5])
